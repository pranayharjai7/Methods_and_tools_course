# %% [markdown]
# # Final Exam — Practice Submission
#
# **Instructions:** Fill in each section. Every cell is labelled with its problem number.
# This is what your submitted notebook should look like.

# %%
import numpy as np
import matplotlib.pyplot as plt

TRAIN_PATH = r'C:\Pranay\Study Material\Masters\Methods and tools for AI applications\final example\train.csv'
TEST_PATH  = r'C:\Pranay\Study Material\Masters\Methods and tools for AI applications\final example\test.csv'

# %%
# --- 1(a) ---
# Load the data files, verify their data shape.

# YOUR CODE HERE

# %%
# --- 1(b) ---
# Reduce the dimension of the input x from 5 to 1.
# Specify the name of the algorithm used: PCA (Principal Component Analysis)

# Step 1: Normalise

# Step 2: Covariance matrix

# Step 3: Eigendecomposition

# Step 4: Sort eigenvalues descending

# Step 5: Project onto PC1

# YOUR CODE HERE

# %%
# --- 1(c) ---
# Plot t vs x1 (x reduced to 1 dimension).
# Decide what would be the most suitable degree for a polynomial fit.

# YOUR CODE HERE

# Decision: degree = ___  because ...

# %%
# --- 1(d) ---
# Perform polynomial regression of t vs x1 on the training data.
# Plot both t and its predicted value vs x1.
# Determine what is the expected uncertainty of the predictions.

DEGREE = 2   # set based on 1(c)

# Build design matrix

# Normal equation: W = (PhiT @ Phi)^{-1} @ PhiT @ t

# Predict

# RMSE (uncertainty)

# Plot

# YOUR CODE HERE

# %%
# --- 1(e) ---
# Using the above procedure, predict for the test dataset. Print the predicted values.

# IMPORTANT: use mu_X, sigma_X, U1, W from training — do NOT recompute from test data!

# Normalise test X

# Project test X onto PC1

# Build test design matrix and predict

# YOUR CODE HERE

# %%
# --- 2(d) ---
# Sample the distribution using the given recipe. For lambda=3,
# show that the histogram matches the PDF.

lam = 3
mu  = 0
N   = 50000

rng = np.random.default_rng(seed=42)

# Generate u1, u2 ~ Uniform[0,1]

# Set s = 1 if u1 < 0.5, else -1

# x = s * lam * log(u2) / sqrt(2)

# Plot histogram + theoretical PDF

# YOUR CODE HERE

# %%
# --- 2(e) ---
# Demonstrate numerically that for three different values of lambda,
# the variance of X is indeed lambda^2.

rng = np.random.default_rng(seed=0)
N   = 100000
mu  = 0

for lam in [1, 3, 5]:   # three different lambda values
    # Generate samples

    # Compute variance

    # Print comparison
    pass

# YOUR CODE HERE
